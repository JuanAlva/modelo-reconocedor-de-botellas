# %%
# !unzip -q /content/data.zip -d /content/

# %%
# !nvidia-smi
# Out:
# Tue Nov 21 18:53:47 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.9/78.2 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/dataset/dataset.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 61.1MB/s]
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/dataset/dataset.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 138MB/s]
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/drive/MyDrive/dataset/dataset.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 220MB/s]
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=/content/drive/MyDrive/dataset/dataset.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 269MB/s]
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=/content/drive/MyDrive/dataset/dataset.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 131M/131M [00:00<00:00, 229MB/s]
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/dataset/dataset.yaml
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/dataset/val/labels.cache... 19 images, 0 backgrounds, 0 corrupt: 100% 19/19 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:04<00:00,  2.38s/it]
#                    all         19         42       0.83      0.762      0.821      0.615
# Speed: 5.2ms preprocess, 23.7ms inference, 0.0ms loss, 8.6ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train2/weights/best.pt data=/content/drive/MyDrive/dataset/dataset.yaml
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/dataset/val/labels.cache... 19 images, 0 backgrounds, 0 corrupt: 100% 19/19 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:04<00:00,  2.37s/it]
#                    all         19         42      0.935      0.683      0.804      0.614
# Speed: 8.1ms preprocess, 21.1ms inference, 0.0ms loss, 6.7ms postprocess per image
# Results saved to runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train3/weights/best.pt data=/content/drive/MyDrive/dataset/dataset.yaml
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/MyDrive/dataset/val/labels.cache... 19 images, 0 backgrounds, 0 corrupt: 100% 19/19 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:06<00:00,  3.07s/it]
#                    all         19         42      0.986       0.69      0.766      0.584
# Speed: 7.4ms preprocess, 50.2ms inference, 0.0ms loss, 15.6ms postprocess per image
# Results saved to runs/detect/val3
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train4/weights/best.pt data=/content/drive/MyDrive/dataset/dataset.yaml
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning /content/drive/MyDrive/dataset/val/labels.cache... 19 images, 0 backgrounds, 0 corrupt: 100% 19/19 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:07<00:00,  3.80s/it]
#                    all         19         42      0.966      0.643      0.751      0.528
# Speed: 10.3ms preprocess, 40.0ms inference, 0.0ms loss, 8.1ms postprocess per image
# Results saved to runs/detect/val4
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train5/weights/best.pt data=/content/drive/MyDrive/dataset/dataset.yaml
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/drive/MyDrive/dataset/val/labels.cache... 19 images, 0 backgrounds, 0 corrupt: 100% 19/19 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:05<00:00,  2.97s/it]
#                    all         19         42      0.831      0.714       0.79      0.569
# Speed: 5.4ms preprocess, 69.4ms inference, 0.0ms loss, 10.9ms postprocess per image
# Results saved to runs/detect/val5
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.5 source=/content/drive/MyDrive/dataset/test
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/3 /content/drive/MyDrive/dataset/test/IMG_0530.png: 480x640 5 botellas, 89.7ms
# video 2/3 (1/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 2 botellas, 85.7ms
# video 2/3 (2/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 2 botellas, 18.2ms
# video 2/3 (3/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 10.0ms
# video 2/3 (4/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 2 botellas, 11.9ms
# video 2/3 (5/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 23.2ms
# video 2/3 (6/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 10.1ms
# video 2/3 (7/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 2 botellas, 18.2ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.5 source=/content/drive/MyDrive/dataset/test
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/3 /content/drive/MyDrive/dataset/test/IMG_0530.png: 480x640 5 botellas, 66.1ms
# video 2/3 (1/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 63.1ms
# video 2/3 (2/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 11.2ms
# video 2/3 (3/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 11.3ms
# video 2/3 (4/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 2 botellas, 11.9ms
# video 2/3 (5/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 2 botellas, 11.6ms
# video 2/3 (6/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 3 botellas, 12.7ms
# video 2/3 (7/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 2 botellas, 11.2ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train3/weights/best.pt conf=0.5 source=/content/drive/MyDrive/dataset/test
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/3 /content/drive/MyDrive/dataset/test/IMG_0530.png: 480x640 5 botellas, 123.2ms
# video 2/3 (1/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 2 botellas, 112.9ms
# video 2/3 (2/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 30.3ms
# video 2/3 (3/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 25.9ms
# video 2/3 (4/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 25.9ms
# video 2/3 (5/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 31.9ms
# video 2/3 (6/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 25.9ms
# video 2/3 (7/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 25.9ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train4/weights/best.pt conf=0.5 source=/content/drive/MyDrive/dataset/test
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/3 /content/drive/MyDrive/dataset/test/IMG_0530.png: 480x640 5 botellas, 63.8ms
# video 2/3 (1/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 68.4ms
# video 2/3 (2/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 40.8ms
# video 2/3 (3/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 40.8ms
# video 2/3 (4/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 38.8ms
# video 2/3 (5/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 30.9ms
# video 2/3 (6/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 31.5ms
# video 2/3 (7/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 30.9ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train5/weights/best.pt conf=0.5 source=/content/drive/MyDrive/dataset/test
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
#
# image 1/3 /content/drive/MyDrive/dataset/test/IMG_0530.png: 480x640 5 botellas, 65.3ms
# video 2/3 (1/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 69.2ms
# video 2/3 (2/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 45.7ms
# video 2/3 (3/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 45.7ms
# video 2/3 (4/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 44.2ms
# video 2/3 (5/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 36.4ms
# video 2/3 (6/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 35.4ms
# video 2/3 (7/185) /content/drive/MyDrive/dataset/test/IMG_0532.MOV: 384x640 1 botella, 35.4ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.5 source=/content/drive/MyDrive/dataset/test/IMG_0530.png
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/dataset/test/IMG_0530.png: 480x640 5 botellas, 89.4ms
# Speed: 5.1ms preprocess, 89.4ms inference, 124.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.5 source=/content/drive/MyDrive/dataset/test/IMG_0530.png
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/drive/MyDrive/dataset/test/IMG_0530.png: 480x640 5 botellas, 62.2ms
# Speed: 3.6ms preprocess, 62.2ms inference, 86.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train3/weights/best.pt conf=0.5 source=/content/drive/MyDrive/dataset/test/IMG_0530.png
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/dataset/test/IMG_0530.png: 480x640 5 botellas, 108.5ms
# Speed: 4.5ms preprocess, 108.5ms inference, 118.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train4/weights/best.pt conf=0.5 source=/content/drive/MyDrive/dataset/test/IMG_0530.png
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/drive/MyDrive/dataset/test/IMG_0530.png: 480x640 5 botellas, 65.4ms
# Speed: 3.5ms preprocess, 65.4ms inference, 99.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train5/weights/best.pt conf=0.5 source=/content/drive/MyDrive/dataset/test/IMG_0530.png
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
#
# image 1/1 /content/drive/MyDrive/dataset/test/IMG_0530.png: 480x640 5 botellas, 101.5ms
# Speed: 4.6ms preprocess, 101.5ms inference, 107.5ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg'):
  display(Image(filename=image_path, height=600))
  print("\n")

# %%
#export your model's weights for future use
from google.colab import files
files.download('./runs/train/exp/weights/best.pt')
